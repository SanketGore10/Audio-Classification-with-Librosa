# %%
pip install librosa
# Out:
# ...
#    ---------------------------------------- 0.0/253.7 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/253.7 kB 991.0 kB/s eta 0:00:01
#    ------------------- -------------------- 122.9/253.7 kB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 122.9/253.7 kB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 122.9/253.7 kB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 122.9/253.7 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- 253.7/253.7 kB 973.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.0 MB 4.5 MB/s eta 0:00:01
#    --- ------------------------------------ 0.1/1.0 MB 4.5 MB/s eta 0:00:01
#    --- ------------------------------------ 0.1/1.0 MB 4.5 MB/s eta 0:00:01
#    ------------- -------------------------- 0.3/1.0 MB 1.7 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import librosa
import librosa.display
import IPython.display as pdi
import matplotlib as plt
# %matplotlib inline

# %%
filename = ""

# %%
plt.figure(figsize=(14,5))

# %%
data, sample_rate = librosa.load(filename)

# %%
librosa.display.waveshow(data, sr= sample_rate)

# %%
pdi.Audio(filename)
